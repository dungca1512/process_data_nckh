# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv", encoding="utf-8")

# %%
df
# Out:
#        STT        Dấu thời gian Họ và tên\n(Có thể không cung cấp)  \
# 0      1.0  19/08/2024 17:19:14                                NaN
# 1      NaN  19/08/2024 18:29:52                                NaN
# 2      NaN  19/08/2024 18:49:30                                NaN
# 3      2.0  19/08/2024 18:51:51                                NaN
# 4      NaN  19/08/2024 18:52:41                   Nguyễn Trọng Tấn
# ..     ...                  ...                                ...
# 384  273.0  24/08/2024 11:54:24                                NaN
# 385  274.0  24/08/2024 11:54:32                   Nguyễn minh hiếu
# 386  275.0  24/08/2024 11:54:36                  Nguyễn Hồng Nhung
# 387  276.0  24/08/2024 15:30:29                                NaN
# 388    NaN  24/08/2024 16:49:42                                NaN
#
#     Email\n(Có thể không cung cấp) Giới tính  Bạn là sinh viên:  \
# 0                              NaN         Nữ        Năm thứ tư
# 1                              NaN        Nam        Năm thứ tư
# 2                              NaN       Khác        Năm thứ tư
# 3                              NaN        Nam        Năm thứ tư
# 4            tan26102003@gmail.com        Nam        Năm thứ tư
# ..                             ...        ...               ...
# 384                            NaN         Nữ        Năm thứ ba
# 385                            NaN        Nam       Năm thứ hai
# 386                            NaN         Nữ       Năm thứ hai
# 387                            NaN        Nam        Năm thứ ba
# 388                            NaN         Nữ        Năm thứ ba
#
#           Ngành đào tạo:  \
# 0    Quản trị kinh doanh
# 1                   Khác
# 2                   Khác
# 3    Quản trị kinh doanh
# 4                   Khác
# ..                   ...
# 384  Quản trị kinh doanh
# 385   Thương mại điện tử
# 386   Thương mại điện tử
# 387   Thương mại điện tử
# 388            Marketing
#
#     Anh/chị và các bạn đã chuẩn bị gì cho công việc tương lai?  \
# 0                                  Đã xác định rõ ràng
# 1                                  Đã xác định rõ ràng
# 2                                        Chưa nghĩ đến
# 3                      Còn phụ thuộc vào lúc ra trường
# 4                                  Đã xác định rõ ràng
# ..                                                 ...
# 384                                      Chưa nghĩ đến
# 385                                Đã xác định rõ ràng
# 386                    Còn phụ thuộc vào lúc ra trường
# 387                           Đã được gia đình sắp xếp
# 388                    Còn phụ thuộc vào lúc ra trường
#
#      Năng lực giao tiếp và hợp tác [Tôi cảm thấy tự tin khi chia sẻ ý kiến của mình trong các cuộc thảo luận nhóm.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 384                                                  2
# 385                                                  4
# 386                                                  2
# 387                                                  4
# 388                                                  4
#
#      Năng lực giao tiếp và hợp tác [Tôi lắng nghe ý kiến của người khác một cách tích cực và tôn trọng.]  \
# 0                                                    4
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  5
# 386                                                  4
# 387                                                  5
# 388                                                  5
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 384  ...
# 385  ...
# 386  ...
# 387  ...
# 388  ...
#
#      Năng lực quản trị bản thân [Tôi có thể cân bằng giữa học tập, làm việc và các hoạt động cá nhân một cách hợp lý.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    4
# 4                                                    2
# ..                                                 ...
# 384                                                  4
# 385                                                  5
# 386                                                  4
# 387                                                  4
# 388                                                  4
#
#      Năng lực quản trị bản thân [Tôi có thể duy trì kỷ luật cá nhân trong việc hoàn thành các công việc đúng hạn.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  4
# 386                                                  4
# 387                                                  5
# 388                                                  5
#
#      Năng lực quản trị bản thân [Tôi có thể tự đặt ra mục tiêu và điều chỉnh kế hoạch làm việc của mình phù hợp với tình hình thực tế để đạt được mục tiêu đề ra.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    5
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  3
# 386                                                  5
# 387                                                  4
# 388                                                  4
#
#      Năng lực quản trị bản thân [Tôi có thể phân chia công việc và thời gian học tập một cách hợp lý để đạt hiệu quả cao nhất.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    4
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  4
# 386                                                  4
# 387                                                  5
# 388                                                  4
#
#      Năng lực công nghệ thông tin [Tôi thành thạo trong việc sử dụng các phần mềm cơ bản như Word, Excel, và PowerPoint.]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    3
# ..                                                 ...
# 384                                                  4
# 385                                                  5
# 386                                                  4
# 387                                                  5
# 388                                                  4
#
#      Năng lực công nghệ thông tin [Tôi có khả năng học và sử dụng các công nghệ và phần mềm mới một cách nhanh chóng.]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 384                                                  3
# 385                                                  4
# 386                                                  2
# 387                                                  4
# 388                                                  3
#
#      Năng lực công nghệ thông tin [Tôi cảm thấy tự tin khi giải quyết các vấn đề kỹ thuật liên quan đến công nghệ thông tin.]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 384                                                  3
# 385                                                  4
# 386                                                  3
# 387                                                  4
# 388                                                  2
#
#      Năng lực công nghệ thông tin [Tôi thường xuyên cập nhật và nâng cao kiến thức về công nghệ thông tin để cải thiện kỹ năng làm việc.]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 384                                                  2
# 385                                                  3
# 386                                                  3
# 387                                                  3
# 388                                                  2
#
#      Trân trọng cảm ơn sự hợp tác của các anh chị và các bạn!!!  \
# 0                                                   Ok
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 384                                                NaN
# 385                                                NaN
# 386                                                NaN
# 387                                                NaN
# 388                                                NaN
#
#      Bạn nhận được phiếu khảo sát này từ ai?
# 0                                        NaN
# 1                            Nguyễn Ngọc Mai
# 2                            Nguyễn Ngọc Mai
# 3                             Nguyễn Ngọc Hà
# 4                            Nguyễn Ngọc Mai
# ..                                       ...
# 384                          Nguyễn Ngọc Mai
# 385                          Nguyễn Ngọc Mai
# 386                          Nguyễn Ngọc Mai
# 387                          Nguyễn Ngọc Mai
# 388                          Nguyễn Ngọc Mai
#
# [389 rows x 34 columns]

# %%
df.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Columns: 34 entries, STT to Bạn nhận được phiếu khảo sát này từ ai?
# dtypes: float64(1), int64(24), object(9)
# memory usage: 103.5+ KB

# %%
df.describe()
# Out:
#               STT  \
# count  276.000000
# mean   138.500000
# std     79.818544
# min      1.000000
# 25%     69.750000
# 50%    138.500000
# 75%    207.250000
# max    276.000000
#
#        Năng lực giao tiếp và hợp tác [Tôi cảm thấy tự tin khi chia sẻ ý kiến của mình trong các cuộc thảo luận nhóm.]  \
# count                                         389.000000
# mean                                            3.524422
# std                                             1.051531
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực giao tiếp và hợp tác [Tôi lắng nghe ý kiến của người khác một cách tích cực và tôn trọng.]  \
# count                                         389.000000
# mean                                            4.020566
# std                                             0.930352
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        Năng lực giao tiếp và hợp tác [Tôi có thể truyền đạt thông tin một cách rõ ràng và hiệu quả.]  \
# count                                         389.000000
# mean                                            3.403599
# std                                             0.943828
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực giao tiếp và hợp tác [Tôi có thể làm việc nhóm để đạt được mục tiêu chung.]  \
# count                                         389.000000
# mean                                            3.807198
# std                                             0.903230
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực giao tiếp và hợp tác [Tôi thích tham gia vào các hoạt động nhóm và đóng góp ý kiến.]  \
# count                                         389.000000
# mean                                            3.465296
# std                                             1.018870
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực sáng tạo [Tôi thích tìm kiếm những cách thức làm việc mới và hiệu quả hơn.]  \
# count                                         389.000000
# mean                                            3.624679
# std                                             0.970178
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực sáng tạo [Tôi không sợ thất bại khi thử nghiệm những ý tưởng mới.]  \
# count                                         389.000000
# mean                                            3.344473
# std                                             0.960349
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực sáng tạo [Tôi thích giải quyết các vấn đề theo những cách khác biệt.]  \
# count                                         389.000000
# mean                                            3.336761
# std                                             0.985572
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực sáng tạo [Tôi có thể nhìn nhận vấn đề từ nhiều góc độ khác nhau.]  \
# count                                         389.000000
# mean                                            3.465296
# std                                             0.917726
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        ...  \
# count  ...
# mean   ...
# std    ...
# min    ...
# 25%    ...
# 50%    ...
# 75%    ...
# max    ...
#
#        Năng lực phân tích công việc [Tôi có thể đưa ra các giải pháp hiệu quả cho các vấn đề từ các kiến thức đã học.]  \
# count                                         389.000000
# mean                                            3.470437
# std                                             0.937355
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực quản trị bản thân [Tôi cảm thấy thoải mái và hiệu quả khi làm việc từ xa.]  \
# count                                         389.000000
# mean                                            3.634961
# std                                             0.960783
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực quản trị bản thân [Tôi có thể cân bằng giữa học tập, làm việc và các hoạt động cá nhân một cách hợp lý.]  \
# count                                          389.00000
# mean                                             3.33419
# std                                              0.97462
# min                                              1.00000
# 25%                                              3.00000
# 50%                                              3.00000
# 75%                                              4.00000
# max                                              5.00000
#
#        Năng lực quản trị bản thân [Tôi có thể duy trì kỷ luật cá nhân trong việc hoàn thành các công việc đúng hạn.]  \
# count                                         389.000000
# mean                                            3.478149
# std                                             1.016696
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực quản trị bản thân [Tôi có thể tự đặt ra mục tiêu và điều chỉnh kế hoạch làm việc của mình phù hợp với tình hình thực tế để đạt được mục tiêu đề ra.]  \
# count                                         389.000000
# mean                                            3.542416
# std                                             0.934105
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực quản trị bản thân [Tôi có thể phân chia công việc và thời gian học tập một cách hợp lý để đạt hiệu quả cao nhất.]  \
# count                                         389.000000
# mean                                            3.380463
# std                                             0.927378
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực công nghệ thông tin [Tôi thành thạo trong việc sử dụng các phần mềm cơ bản như Word, Excel, và PowerPoint.]  \
# count                                         389.000000
# mean                                            3.383033
# std                                             0.997326
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực công nghệ thông tin [Tôi có khả năng học và sử dụng các công nghệ và phần mềm mới một cách nhanh chóng.]  \
# count                                         389.000000
# mean                                            3.295630
# std                                             0.972565
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực công nghệ thông tin [Tôi cảm thấy tự tin khi giải quyết các vấn đề kỹ thuật liên quan đến công nghệ thông tin.]  \
# count                                         389.000000
# mean                                            3.107969
# std                                             1.059402
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực công nghệ thông tin [Tôi thường xuyên cập nhật và nâng cao kiến thức về công nghệ thông tin để cải thiện kỹ năng làm việc.]
# count                                         389.000000
# mean                                            3.146530
# std                                             1.028771
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# ## Trước hết, ta cần lọc hết tất cả những trường không cần thiết, bao gồm những trường có các giá trị NaN để lấy ra được các trường bắt buộc

# %%
df2 = df.iloc[:, 4:-2]

# %%
df2
# Out:
#     Giới tính  Bạn là sinh viên:       Ngành đào tạo:  \
# 0           Nữ        Năm thứ tư  Quản trị kinh doanh
# 1          Nam        Năm thứ tư                 Khác
# 2         Khác        Năm thứ tư                 Khác
# 3          Nam        Năm thứ tư  Quản trị kinh doanh
# 4          Nam        Năm thứ tư                 Khác
# ..         ...               ...                  ...
# 384         Nữ        Năm thứ ba  Quản trị kinh doanh
# 385        Nam       Năm thứ hai   Thương mại điện tử
# 386         Nữ       Năm thứ hai   Thương mại điện tử
# 387        Nam        Năm thứ ba   Thương mại điện tử
# 388         Nữ        Năm thứ ba            Marketing
#
#     Anh/chị và các bạn đã chuẩn bị gì cho công việc tương lai?  \
# 0                                  Đã xác định rõ ràng
# 1                                  Đã xác định rõ ràng
# 2                                        Chưa nghĩ đến
# 3                      Còn phụ thuộc vào lúc ra trường
# 4                                  Đã xác định rõ ràng
# ..                                                 ...
# 384                                      Chưa nghĩ đến
# 385                                Đã xác định rõ ràng
# 386                    Còn phụ thuộc vào lúc ra trường
# 387                           Đã được gia đình sắp xếp
# 388                    Còn phụ thuộc vào lúc ra trường
#
#      Năng lực giao tiếp và hợp tác [Tôi cảm thấy tự tin khi chia sẻ ý kiến của mình trong các cuộc thảo luận nhóm.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 384                                                  2
# 385                                                  4
# 386                                                  2
# 387                                                  4
# 388                                                  4
#
#      Năng lực giao tiếp và hợp tác [Tôi lắng nghe ý kiến của người khác một cách tích cực và tôn trọng.]  \
# 0                                                    4
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  5
# 386                                                  4
# 387                                                  5
# 388                                                  5
#
#      Năng lực giao tiếp và hợp tác [Tôi có thể truyền đạt thông tin một cách rõ ràng và hiệu quả.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    4
# 4                                                    2
# ..                                                 ...
# 384                                                  2
# 385                                                  5
# 386                                                  2
# 387                                                  4
# 388                                                  4
#
#      Năng lực giao tiếp và hợp tác [Tôi có thể làm việc nhóm để đạt được mục tiêu chung.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    5
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  5
# 386                                                  3
# 387                                                  3
# 388                                                  4
#
#      Năng lực giao tiếp và hợp tác [Tôi thích tham gia vào các hoạt động nhóm và đóng góp ý kiến.]  \
# 0                                                    4
# 1                                                    1
# 2                                                    1
# 3                                                    4
# 4                                                    2
# ..                                                 ...
# 384                                                  1
# 385                                                  3
# 386                                                  2
# 387                                                  3
# 388                                                  4
#
#      Năng lực sáng tạo [Tôi thích tìm kiếm những cách thức làm việc mới và hiệu quả hơn.]  \
# 0                                                    4
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  4
# 386                                                  5
# 387                                                  4
# 388                                                  3
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 384  ...
# 385  ...
# 386  ...
# 387  ...
# 388  ...
#
#      Năng lực phân tích công việc [Tôi có thể đưa ra các giải pháp hiệu quả cho các vấn đề từ các kiến thức đã học.]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 384                                                  4
# 385                                                  5
# 386                                                  5
# 387                                                  5
# 388                                                  4
#
#      Năng lực quản trị bản thân [Tôi cảm thấy thoải mái và hiệu quả khi làm việc từ xa.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    2
# ..                                                 ...
# 384                                                  4
# 385                                                  5
# 386                                                  4
# 387                                                  4
# 388                                                  4
#
#      Năng lực quản trị bản thân [Tôi có thể cân bằng giữa học tập, làm việc và các hoạt động cá nhân một cách hợp lý.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    4
# 4                                                    2
# ..                                                 ...
# 384                                                  4
# 385                                                  5
# 386                                                  4
# 387                                                  4
# 388                                                  4
#
#      Năng lực quản trị bản thân [Tôi có thể duy trì kỷ luật cá nhân trong việc hoàn thành các công việc đúng hạn.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  4
# 386                                                  4
# 387                                                  5
# 388                                                  5
#
#      Năng lực quản trị bản thân [Tôi có thể tự đặt ra mục tiêu và điều chỉnh kế hoạch làm việc của mình phù hợp với tình hình thực tế để đạt được mục tiêu đề ra.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    5
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  3
# 386                                                  5
# 387                                                  4
# 388                                                  4
#
#      Năng lực quản trị bản thân [Tôi có thể phân chia công việc và thời gian học tập một cách hợp lý để đạt hiệu quả cao nhất.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    4
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  4
# 386                                                  4
# 387                                                  5
# 388                                                  4
#
#      Năng lực công nghệ thông tin [Tôi thành thạo trong việc sử dụng các phần mềm cơ bản như Word, Excel, và PowerPoint.]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    3
# ..                                                 ...
# 384                                                  4
# 385                                                  5
# 386                                                  4
# 387                                                  5
# 388                                                  4
#
#      Năng lực công nghệ thông tin [Tôi có khả năng học và sử dụng các công nghệ và phần mềm mới một cách nhanh chóng.]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 384                                                  3
# 385                                                  4
# 386                                                  2
# 387                                                  4
# 388                                                  3
#
#      Năng lực công nghệ thông tin [Tôi cảm thấy tự tin khi giải quyết các vấn đề kỹ thuật liên quan đến công nghệ thông tin.]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 384                                                  3
# 385                                                  4
# 386                                                  3
# 387                                                  4
# 388                                                  2
#
#      Năng lực công nghệ thông tin [Tôi thường xuyên cập nhật và nâng cao kiến thức về công nghệ thông tin để cải thiện kỹ năng làm việc.]
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 384                                                  2
# 385                                                  3
# 386                                                  3
# 387                                                  3
# 388                                                  2
#
# [389 rows x 28 columns]

# %% [markdown]
# ### Sau khi lọc được các trường bắt buộc, ta chỉ xét tới các trường số để dễ xử lý, bằng cách sử dụng hàm describe() để lấy ra các giá trị thống kê của các trường số này

# %%
df3 = df2.iloc[:, 4:]

# %%
df3
# Out:
#      Năng lực giao tiếp và hợp tác [Tôi cảm thấy tự tin khi chia sẻ ý kiến của mình trong các cuộc thảo luận nhóm.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 384                                                  2
# 385                                                  4
# 386                                                  2
# 387                                                  4
# 388                                                  4
#
#      Năng lực giao tiếp và hợp tác [Tôi lắng nghe ý kiến của người khác một cách tích cực và tôn trọng.]  \
# 0                                                    4
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  5
# 386                                                  4
# 387                                                  5
# 388                                                  5
#
#      Năng lực giao tiếp và hợp tác [Tôi có thể truyền đạt thông tin một cách rõ ràng và hiệu quả.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    4
# 4                                                    2
# ..                                                 ...
# 384                                                  2
# 385                                                  5
# 386                                                  2
# 387                                                  4
# 388                                                  4
#
#      Năng lực giao tiếp và hợp tác [Tôi có thể làm việc nhóm để đạt được mục tiêu chung.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    5
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  5
# 386                                                  3
# 387                                                  3
# 388                                                  4
#
#      Năng lực giao tiếp và hợp tác [Tôi thích tham gia vào các hoạt động nhóm và đóng góp ý kiến.]  \
# 0                                                    4
# 1                                                    1
# 2                                                    1
# 3                                                    4
# 4                                                    2
# ..                                                 ...
# 384                                                  1
# 385                                                  3
# 386                                                  2
# 387                                                  3
# 388                                                  4
#
#      Năng lực sáng tạo [Tôi thích tìm kiếm những cách thức làm việc mới và hiệu quả hơn.]  \
# 0                                                    4
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  4
# 386                                                  5
# 387                                                  4
# 388                                                  3
#
#      Năng lực sáng tạo [Tôi không sợ thất bại khi thử nghiệm những ý tưởng mới.]  \
# 0                                                    4
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 384                                                  2
# 385                                                  4
# 386                                                  4
# 387                                                  3
# 388                                                  3
#
#      Năng lực sáng tạo [Tôi thích giải quyết các vấn đề theo những cách khác biệt.]  \
# 0                                                    4
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 384                                                  2
# 385                                                  3
# 386                                                  4
# 387                                                  3
# 388                                                  2
#
#      Năng lực sáng tạo [Tôi có thể nhìn nhận vấn đề từ nhiều góc độ khác nhau.]  \
# 0                                                    4
# 1                                                    1
# 2                                                    1
# 3                                                    4
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  3
# 386                                                  3
# 387                                                  4
# 388                                                  3
#
#      Năng lực sáng tạo [Tôi thích tham gia vào các hoạt động đòi hỏi sự sáng tạo.]  \
# 0                                                    4
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 384                                                  2
# 385                                                  5
# 386                                                  4
# 387                                                  3
# 388                                                  3
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 384  ...
# 385  ...
# 386  ...
# 387  ...
# 388  ...
#
#      Năng lực phân tích công việc [Tôi có thể đưa ra các giải pháp hiệu quả cho các vấn đề từ các kiến thức đã học.]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 384                                                  4
# 385                                                  5
# 386                                                  5
# 387                                                  5
# 388                                                  4
#
#      Năng lực quản trị bản thân [Tôi cảm thấy thoải mái và hiệu quả khi làm việc từ xa.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    2
# ..                                                 ...
# 384                                                  4
# 385                                                  5
# 386                                                  4
# 387                                                  4
# 388                                                  4
#
#      Năng lực quản trị bản thân [Tôi có thể cân bằng giữa học tập, làm việc và các hoạt động cá nhân một cách hợp lý.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    4
# 4                                                    2
# ..                                                 ...
# 384                                                  4
# 385                                                  5
# 386                                                  4
# 387                                                  4
# 388                                                  4
#
#      Năng lực quản trị bản thân [Tôi có thể duy trì kỷ luật cá nhân trong việc hoàn thành các công việc đúng hạn.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  4
# 386                                                  4
# 387                                                  5
# 388                                                  5
#
#      Năng lực quản trị bản thân [Tôi có thể tự đặt ra mục tiêu và điều chỉnh kế hoạch làm việc của mình phù hợp với tình hình thực tế để đạt được mục tiêu đề ra.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    5
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  3
# 386                                                  5
# 387                                                  4
# 388                                                  4
#
#      Năng lực quản trị bản thân [Tôi có thể phân chia công việc và thời gian học tập một cách hợp lý để đạt hiệu quả cao nhất.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    4
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  4
# 386                                                  4
# 387                                                  5
# 388                                                  4
#
#      Năng lực công nghệ thông tin [Tôi thành thạo trong việc sử dụng các phần mềm cơ bản như Word, Excel, và PowerPoint.]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    3
# ..                                                 ...
# 384                                                  4
# 385                                                  5
# 386                                                  4
# 387                                                  5
# 388                                                  4
#
#      Năng lực công nghệ thông tin [Tôi có khả năng học và sử dụng các công nghệ và phần mềm mới một cách nhanh chóng.]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 384                                                  3
# 385                                                  4
# 386                                                  2
# 387                                                  4
# 388                                                  3
#
#      Năng lực công nghệ thông tin [Tôi cảm thấy tự tin khi giải quyết các vấn đề kỹ thuật liên quan đến công nghệ thông tin.]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 384                                                  3
# 385                                                  4
# 386                                                  3
# 387                                                  4
# 388                                                  2
#
#      Năng lực công nghệ thông tin [Tôi thường xuyên cập nhật và nâng cao kiến thức về công nghệ thông tin để cải thiện kỹ năng làm việc.]
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 384                                                  2
# 385                                                  3
# 386                                                  3
# 387                                                  3
# 388                                                  2
#
# [389 rows x 24 columns]

# %%
df3.describe(include="all")
# Out:
#        Năng lực giao tiếp và hợp tác [Tôi cảm thấy tự tin khi chia sẻ ý kiến của mình trong các cuộc thảo luận nhóm.]  \
# count                                         389.000000
# mean                                            3.524422
# std                                             1.051531
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực giao tiếp và hợp tác [Tôi lắng nghe ý kiến của người khác một cách tích cực và tôn trọng.]  \
# count                                         389.000000
# mean                                            4.020566
# std                                             0.930352
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        Năng lực giao tiếp và hợp tác [Tôi có thể truyền đạt thông tin một cách rõ ràng và hiệu quả.]  \
# count                                         389.000000
# mean                                            3.403599
# std                                             0.943828
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực giao tiếp và hợp tác [Tôi có thể làm việc nhóm để đạt được mục tiêu chung.]  \
# count                                         389.000000
# mean                                            3.807198
# std                                             0.903230
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực giao tiếp và hợp tác [Tôi thích tham gia vào các hoạt động nhóm và đóng góp ý kiến.]  \
# count                                         389.000000
# mean                                            3.465296
# std                                             1.018870
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực sáng tạo [Tôi thích tìm kiếm những cách thức làm việc mới và hiệu quả hơn.]  \
# count                                         389.000000
# mean                                            3.624679
# std                                             0.970178
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực sáng tạo [Tôi không sợ thất bại khi thử nghiệm những ý tưởng mới.]  \
# count                                         389.000000
# mean                                            3.344473
# std                                             0.960349
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực sáng tạo [Tôi thích giải quyết các vấn đề theo những cách khác biệt.]  \
# count                                         389.000000
# mean                                            3.336761
# std                                             0.985572
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực sáng tạo [Tôi có thể nhìn nhận vấn đề từ nhiều góc độ khác nhau.]  \
# count                                         389.000000
# mean                                            3.465296
# std                                             0.917726
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực sáng tạo [Tôi thích tham gia vào các hoạt động đòi hỏi sự sáng tạo.]  \
# count                                         389.000000
# mean                                            3.519280
# std                                             0.991075
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        ...  \
# count  ...
# mean   ...
# std    ...
# min    ...
# 25%    ...
# 50%    ...
# 75%    ...
# max    ...
#
#        Năng lực phân tích công việc [Tôi có thể đưa ra các giải pháp hiệu quả cho các vấn đề từ các kiến thức đã học.]  \
# count                                         389.000000
# mean                                            3.470437
# std                                             0.937355
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực quản trị bản thân [Tôi cảm thấy thoải mái và hiệu quả khi làm việc từ xa.]  \
# count                                         389.000000
# mean                                            3.634961
# std                                             0.960783
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực quản trị bản thân [Tôi có thể cân bằng giữa học tập, làm việc và các hoạt động cá nhân một cách hợp lý.]  \
# count                                          389.00000
# mean                                             3.33419
# std                                              0.97462
# min                                              1.00000
# 25%                                              3.00000
# 50%                                              3.00000
# 75%                                              4.00000
# max                                              5.00000
#
#        Năng lực quản trị bản thân [Tôi có thể duy trì kỷ luật cá nhân trong việc hoàn thành các công việc đúng hạn.]  \
# count                                         389.000000
# mean                                            3.478149
# std                                             1.016696
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực quản trị bản thân [Tôi có thể tự đặt ra mục tiêu và điều chỉnh kế hoạch làm việc của mình phù hợp với tình hình thực tế để đạt được mục tiêu đề ra.]  \
# count                                         389.000000
# mean                                            3.542416
# std                                             0.934105
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực quản trị bản thân [Tôi có thể phân chia công việc và thời gian học tập một cách hợp lý để đạt hiệu quả cao nhất.]  \
# count                                         389.000000
# mean                                            3.380463
# std                                             0.927378
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực công nghệ thông tin [Tôi thành thạo trong việc sử dụng các phần mềm cơ bản như Word, Excel, và PowerPoint.]  \
# count                                         389.000000
# mean                                            3.383033
# std                                             0.997326
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực công nghệ thông tin [Tôi có khả năng học và sử dụng các công nghệ và phần mềm mới một cách nhanh chóng.]  \
# count                                         389.000000
# mean                                            3.295630
# std                                             0.972565
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực công nghệ thông tin [Tôi cảm thấy tự tin khi giải quyết các vấn đề kỹ thuật liên quan đến công nghệ thông tin.]  \
# count                                         389.000000
# mean                                            3.107969
# std                                             1.059402
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực công nghệ thông tin [Tôi thường xuyên cập nhật và nâng cao kiến thức về công nghệ thông tin để cải thiện kỹ năng làm việc.]
# count                                         389.000000
# mean                                            3.146530
# std                                             1.028771
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
# [8 rows x 24 columns]

# %%
import seaborn as sns

sns.kdeplot(df3['Năng lực quản trị bản thân [Tôi có thể tự đặt ra mục tiêu và điều chỉnh kế hoạch làm việc của mình phù hợp với tình hình thực tế để đạt được mục tiêu đề ra.]'], shade=True)
plt.title('KDE of column_name')
plt.xlabel('Values')
plt.ylabel('Density')
plt.show()
# Out:
# /tmp/ipykernel_36784/2274541254.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df3['Năng lực quản trị bản thân [Tôi có thể tự đặt ra mục tiêu và điều chỉnh kế hoạch làm việc của mình phù hợp với tình hình thực tế để đạt được mục tiêu đề ra.]'], shade=True)

# %% [markdown]
# ## Tại đây, ta thấy rằng tất cả các trường trong df đều có phân bố giống nhau, bao gồm trung vị, độ lệch chuẩn, phương sai cũng như kỳ vọng. Do đó, ta hoàn toàn có thể gộp các trường có cùng ý nghĩa lại thành một trường duy nhất để giảm số chiều dữ liệu mà vẫn có thể giữ lại thông tin cần thiết.

# %%
df4 = pd.DataFrame()

# %%
df4['Giao tiếp và hợp tác'] = df3.iloc[:, :5].mean(axis=1)
df4["Năng lực sáng tạo"] = df3.iloc[:, 5:10].mean(axis=1)
df4["Năng lực phân tích công việc"] = df3.iloc[:, 10:15].mean(axis=1)
df4["Năng lực quản trị bản thân"] = df3.iloc[:, 15:20].mean(axis=1)
df4["Năng lực công nghệ thông tin"] = df3.iloc[:, 20:25].mean(axis=1)

# %%
df4
# Out:
#      Giao tiếp và hợp tác  Năng lực sáng tạo  Năng lực phân tích công việc  \
# 0                     3.4                4.0                           2.8
# 1                     1.0                1.0                           1.0
# 2                     1.0                1.0                           1.0
# 3                     3.6                2.6                           3.0
# 4                     2.0                2.0                           2.0
# ..                    ...                ...                           ...
# 385                   4.4                3.8                           4.0
# 386                   2.6                4.0                           3.4
# 387                   3.8                3.4                           4.0
# 388                   4.2                2.8                           3.0
# 389                   NaN                NaN                           NaN
#
#      Năng lực quản trị bản thân  Năng lực công nghệ thông tin
# 0                           3.0                          2.00
# 1                           1.0                          1.00
# 2                           1.0                          1.00
# 3                           3.4                          2.00
# 4                           2.0                          3.00
# ..                          ...                           ...
# 385                         4.2                          4.00
# 386                         4.2                          3.00
# 387                         4.4                          4.00
# 388                         4.2                          2.75
# 389                         NaN                           NaN
#
# [390 rows x 5 columns]

# %%
df4.describe()
# Out:
#        Giao tiếp và hợp tác  Năng lực sáng tạo  Năng lực phân tích công việc  \
# count            389.000000         389.000000                    389.000000
# mean               3.644216           3.458098                      3.395887
# std                0.749226           0.750270                      0.712614
# min                1.000000           1.000000                      1.000000
# 25%                3.200000           3.000000                      3.000000
# 50%                3.800000           3.400000                      3.400000
# 75%                4.200000           4.000000                      3.800000
# max                5.000000           5.000000                      5.000000
#
#        Năng lực quản trị bản thân  Năng lực công nghệ thông tin
# count                  389.000000                    389.000000
# mean                     3.474036                      3.233290
# std                      0.748242                      0.861013
# min                      1.000000                      1.000000
# 25%                      3.000000                      2.750000
# 50%                      3.600000                      3.250000
# 75%                      4.000000                      4.000000
# max                      5.000000                      5.000000

# %%
row_mean = df4.mean()
df_mean = pd.DataFrame(data=row_mean).T
df4 = pd.concat([df4, df_mean], ignore_index=True)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def get_radar_chart(df):
    # Set seaborn style and color palette
    sns.set(style="whitegrid")

    data = df.iloc[-1]
    categories = list(data.index)
    N = len(categories)

    # Calculate angles for each category
    angles = [n / float(N) * 2 * np.pi for n in range(N)]
    angles += angles[:1]

    # Close the plot by repeating the first value
    data = list(data)
    data += data[:1]

    # Initialize the radar chart
    plt.figure(figsize=(8, 8))
    ax = plt.subplot(111, polar=True)

    # Draw the outline and fill area with seaborn color
    color = sns.color_palette("husl", 1)[0]
    ax.plot(angles, data, 'o-', linewidth=2, color=color)
    ax.fill(angles, data, alpha=0.25, color=color)

    # Add category labels
    plt.xticks(angles[:-1], categories, color='black', size=10)

    # Set y-axis labels and range
    ax.yaxis.set_ticks([0, 1, 2, 3, 4, 5])
    ax.yaxis.set_tick_params(labelsize=8)
    plt.ylim(0, 6)

    plt.show()

# %%
get_radar_chart(df4)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd

def reduce_dimensions_with_pca(df, n_components=5):
    """
    Reduce the dimensionality of the data using PCA (Principal Component Analysis).

    Parameters:
    - df (pandas.DataFrame): The input data to be reduced in dimensionality.
    - n_components (int): The number of principal components to retain after reduction.

    Returns:
    - df_pca (pandas.DataFrame): The data after dimensionality reduction.
    - pca (PCA object): The PCA object for further inspection if needed.
    """
    # Standardize the data
    scaler = StandardScaler()
    df_scaled = scaler.fit_transform(df.select_dtypes(include=[np.number]))

    # Perform PCA
    pca = PCA(n_components=n_components)
    df_pca = pca.fit_transform(df_scaled)

    # Plot the cumulative explained variance by PCA components
    plt.figure(figsize=(8, 6))
    plt.plot(range(1, n_components + 1), pca.explained_variance_ratio_.cumsum(), marker='o', linestyle='--')
    plt.title('Cumulative Explained Variance by PCA Components')
    plt.xlabel('Number of Components')
    plt.ylabel('Cumulative Explained Variance')
    plt.show()

    # Create a DataFrame from the PCA results
    df_pca = pd.DataFrame(df_pca, columns=[f'PC{i}' for i in range(1, n_components + 1)])

    return df_pca, pca

# %%
df_pca, pca_model = reduce_dimensions_with_pca(df3,  n_components=5)
df_pca
# Out:
#            PC1       PC2       PC3       PC4       PC5
# 0    -1.823295 -2.400738 -0.247410 -0.105295 -0.933614
# 1   -12.560125  0.365799 -0.285438  0.451325  0.713894
# 2   -12.560125  0.365799 -0.285438  0.451325  0.713894
# 3    -2.377009 -1.144969  2.417060  0.271912  3.460979
# 4    -6.674380  1.772049 -1.364571  0.440125  0.758404
# ..         ...       ...       ...       ...       ...
# 384  -3.879225  2.498559  0.951752 -0.361387 -1.170596
# 385   3.187708  0.712726  0.589889 -0.709602 -0.028885
# 386   0.086865  1.047667  1.397302  0.036911 -2.490980
# 387   2.399273  1.781612  1.275648 -0.107947  0.007372
# 388  -0.167892  0.218132  2.031820 -2.264709  0.376251
#
# [389 rows x 5 columns]

# %%
df_pca.describe()
# Out:
#                 PC1           PC2         PC3           PC4           PC5
# count  3.890000e+02  3.890000e+02  389.000000  3.890000e+02  3.890000e+02
# mean  -1.826588e-17  3.196529e-17    0.000000 -5.936411e-17 -3.196529e-17
# std    3.104271e+00  1.400503e+00    1.218657  1.162038e+00  1.002187e+00
# min   -1.256012e+01 -6.836851e+00   -4.064599 -7.839884e+00 -3.090594e+00
# 25%   -1.856538e+00 -8.983266e-01   -0.642195 -6.174936e-01 -5.976834e-01
# 50%    1.206860e-01  4.508782e-02   -0.119065  1.403048e-01  4.872341e-02
# 75%    1.969567e+00  6.864128e-01    0.723765  5.900333e-01  6.215073e-01
# max    7.936872e+00  5.776203e+00    4.339145  3.632363e+00  5.376289e+00

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
df_scaled = scaler.fit_transform(df3.select_dtypes(include=[np.number]))
print(df_scaled.shape)
# Out:
# (389, 24)

# %%
df_pca.shape
# Out:
# (389, 5)
