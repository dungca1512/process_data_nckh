# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv", encoding="utf-8")

# %%
df
# Out:
#        STT        Dấu thời gian Họ và tên\n(Có thể không cung cấp)  \
# 0      1.0  19/08/2024 17:19:14                                NaN
# 1      NaN  19/08/2024 18:29:52                                NaN
# 2      NaN  19/08/2024 18:49:30                                NaN
# 3      2.0  19/08/2024 18:51:51                                NaN
# 4      NaN  19/08/2024 18:52:41                   Nguyễn Trọng Tấn
# ..     ...                  ...                                ...
# 384  273.0  24/08/2024 11:54:24                                NaN
# 385  274.0  24/08/2024 11:54:32                   Nguyễn minh hiếu
# 386  275.0  24/08/2024 11:54:36                  Nguyễn Hồng Nhung
# 387  276.0  24/08/2024 15:30:29                                NaN
# 388    NaN  24/08/2024 16:49:42                                NaN
#
#     Email\n(Có thể không cung cấp) Giới tính  Bạn là sinh viên:  \
# 0                              NaN         Nữ        Năm thứ tư
# 1                              NaN        Nam        Năm thứ tư
# 2                              NaN       Khác        Năm thứ tư
# 3                              NaN        Nam        Năm thứ tư
# 4            tan26102003@gmail.com        Nam        Năm thứ tư
# ..                             ...        ...               ...
# 384                            NaN         Nữ        Năm thứ ba
# 385                            NaN        Nam       Năm thứ hai
# 386                            NaN         Nữ       Năm thứ hai
# 387                            NaN        Nam        Năm thứ ba
# 388                            NaN         Nữ        Năm thứ ba
#
#           Ngành đào tạo:  \
# 0    Quản trị kinh doanh
# 1                   Khác
# 2                   Khác
# 3    Quản trị kinh doanh
# 4                   Khác
# ..                   ...
# 384  Quản trị kinh doanh
# 385   Thương mại điện tử
# 386   Thương mại điện tử
# 387   Thương mại điện tử
# 388            Marketing
#
#     Anh/chị và các bạn đã chuẩn bị gì cho công việc tương lai?  \
# 0                                  Đã xác định rõ ràng
# 1                                  Đã xác định rõ ràng
# 2                                        Chưa nghĩ đến
# 3                      Còn phụ thuộc vào lúc ra trường
# 4                                  Đã xác định rõ ràng
# ..                                                 ...
# 384                                      Chưa nghĩ đến
# 385                                Đã xác định rõ ràng
# 386                    Còn phụ thuộc vào lúc ra trường
# 387                           Đã được gia đình sắp xếp
# 388                    Còn phụ thuộc vào lúc ra trường
#
#      Năng lực giao tiếp và hợp tác [Tôi cảm thấy tự tin khi chia sẻ ý kiến của mình trong các cuộc thảo luận nhóm.]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 384                                                  2
# 385                                                  4
# 386                                                  2
# 387                                                  4
# 388                                                  4
#
#      Năng lực giao tiếp và hợp tác [Tôi lắng nghe ý kiến của người khác một cách tích cực và tôn trọng.]  \
# 0                                                    4
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 384                                                  3
# 385                                                  5
# 386                                                  4
# 387                                                  5
# 388                                                  5
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 384  ...
# 385  ...
# 386  ...
# 387  ...
# 388  ...
#
#     Năng lực công nghệ thông tin [Tôi cảm thấy tự tin khi giải quyết các vấn đề kỹ thuật liên quan đến công nghệ thông tin.]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 384                                                  3
# 385                                                  4
# 386                                                  3
# 387                                                  4
# 388                                                  2
#
#      Năng lực công nghệ thông tin [Tôi thường xuyên cập nhật và nâng cao kiến thức về công nghệ thông tin để cải thiện kỹ năng làm việc.]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 384                                                  2
# 385                                                  3
# 386                                                  3
# 387                                                  3
# 388                                                  2
#
#      Năng lực công nghệ thông tin [Tôi có khả năng tích hợp và sử dụng các công cụ công nghệ vào học tập và công việc hàng ngày.]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    5
# 4                                                    3
# ..                                                 ...
# 384                                                  3
# 385                                                  5
# 386                                                  4
# 387                                                  5
# 388                                                  4
#
#      Áp lực công việc [Tôi thường xuyên lo lắng về công việc trong nền kinh tế số]  \
# 0                                                    3
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    4
# ..                                                 ...
# 384                                                  5
# 385                                                  2
# 386                                                  5
# 387                                                  4
# 388                                                  4
#
#      Áp lực công việc [Tôi cảm thấy không tự tin về năng lực của mình trước yêu cầu của nền kinh tế số]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    4
# ..                                                 ...
# 384                                                  4
# 385                                                  1
# 386                                                  4
# 387                                                  2
# 388                                                  3
#
#      Áp lực công việc [Tôi cảm thấy không thể học thêm các điều mới để áp ứng yêu cầu công việc trong nền kinh tế số]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    4
# ..                                                 ...
# 384                                                  3
# 385                                                  1
# 386                                                  3
# 387                                                  3
# 388                                                  3
#
#      Áp lực công việc [Tôi cho rằng yêu cầu công việc trong nền kinh tế số vượt quá năng lực của tôi]  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    4
# ..                                                 ...
# 384                                                  4
# 385                                                  2
# 386                                                  4
# 387                                                  4
# 388                                                  3
#
#      Áp lực công việc [Tôi thường xuyên mệt mỏi khi nghĩ về công việc trong tương lai]  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    3
# 4                                                    4
# ..                                                 ...
# 384                                                  5
# 385                                                  2
# 386                                                  5
# 387                                                  5
# 388                                                  4
#
#      Trân trọng cảm ơn sự hợp tác của các anh chị và các bạn!!!  \
# 0                                                   Ok
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 384                                                NaN
# 385                                                NaN
# 386                                                NaN
# 387                                                NaN
# 388                                                NaN
#
#      Bạn nhận được phiếu khảo sát này từ ai?
# 0                                        NaN
# 1                            Nguyễn Ngọc Mai
# 2                            Nguyễn Ngọc Mai
# 3                             Nguyễn Ngọc Hà
# 4                            Nguyễn Ngọc Mai
# ..                                       ...
# 384                          Nguyễn Ngọc Mai
# 385                          Nguyễn Ngọc Mai
# 386                          Nguyễn Ngọc Mai
# 387                          Nguyễn Ngọc Mai
# 388                          Nguyễn Ngọc Mai
#
# [389 rows x 40 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 40 columns):
#  #   Column                                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                                         --------------  -----
#  0   STT                                                                                                                                                            276 non-null    float64
#  1   Dấu thời gian                                                                                                                                                  389 non-null    object
#  2   Họ và tên
# (Có thể không cung cấp)                                                                                                                              143 non-null    object
#  3   Email
# (Có thể không cung cấp)                                                                                                                                  45 non-null     object
#  4   Giới tính                                                                                                                                                      389 non-null    object
#  5   Bạn là sinh viên:                                                                                                                                              389 non-null    object
#  6   Ngành đào tạo:                                                                                                                                                 389 non-null    object
#  7   Anh/chị và các bạn đã chuẩn bị gì cho công việc tương lai?                                                                                                     389 non-null    object
#  8   Năng lực giao tiếp và hợp tác [Tôi cảm thấy tự tin khi chia sẻ ý kiến của mình trong các cuộc thảo luận nhóm.]                                                 389 non-null    int64
#  9   Năng lực giao tiếp và hợp tác [Tôi lắng nghe ý kiến của người khác một cách tích cực và tôn trọng.]                                                            389 non-null    int64
#  10  Năng lực giao tiếp và hợp tác [Tôi có thể truyền đạt thông tin một cách rõ ràng và hiệu quả.]                                                                  389 non-null    object
#  11  Năng lực giao tiếp và hợp tác [Tôi có thể làm việc nhóm để đạt được mục tiêu chung.]                                                                           389 non-null    int64
#  12  Năng lực giao tiếp và hợp tác [Tôi thích tham gia vào các hoạt động nhóm và đóng góp ý kiến.]                                                                  389 non-null    int64
#  13  Năng lực sáng tạo [Tôi thích tìm kiếm những cách thức làm việc mới và hiệu quả hơn.]                                                                           389 non-null    int64
#  14  Năng lực sáng tạo [Tôi không sợ thất bại khi thử nghiệm những ý tưởng mới.]                                                                                    389 non-null    int64
#  15  Năng lực sáng tạo [Tôi thích giải quyết các vấn đề theo những cách khác biệt.]                                                                                 389 non-null    int64
#  16  Năng lực sáng tạo [Tôi có thể nhìn nhận vấn đề từ nhiều góc độ khác nhau.]                                                                                     389 non-null    int64
#  17  Năng lực sáng tạo [Tôi thích tham gia vào các hoạt động đòi hỏi sự sáng tạo.]                                                                                  389 non-null    int64
#  18  Năng lực phân tích công việc [Tôi có thể thu thập và phân tích thông tin một cách hiệu quả.]                                                                   389 non-null    int64
#  19  Năng lực phân tích công việc [Tôi có thể nhận biết được các vấn đề và nguyên nhân gốc rễ của chúng.]                                                           389 non-null    int64
#  20  Năng lực phân tích công việc [Tôi có thể đánh giá các lựa chọn khác nhau và chọn ra lựa chọn tốt nhất để giải quyết một vấn đề.]                               389 non-null    int64
#  21  Năng lực phân tích công việc [Tôi có thể xác định được các mối quan hệ giữa các yếu tố khác nhau.]                                                             389 non-null    int64
#  22  Năng lực phân tích công việc [Tôi có thể đưa ra các giải pháp hiệu quả cho các vấn đề từ các kiến thức đã học.]                                                389 non-null    int64
#  23  Năng lực quản trị bản thân [Tôi cảm thấy thoải mái và hiệu quả khi làm việc từ xa.]                                                                            389 non-null    int64
#  24  Năng lực quản trị bản thân [Tôi có thể cân bằng giữa học tập, làm việc và các hoạt động cá nhân một cách hợp lý.]                                              389 non-null    int64
#  25  Năng lực quản trị bản thân [Tôi có thể duy trì kỷ luật cá nhân trong việc hoàn thành các công việc đúng hạn.]                                                  389 non-null    int64
#  26  Năng lực quản trị bản thân [Tôi có thể tự đặt ra mục tiêu và điều chỉnh kế hoạch làm việc của mình phù hợp với tình hình thực tế để đạt được mục tiêu đề ra.]  389 non-null    int64
#  27  Năng lực quản trị bản thân [Tôi có thể phân chia công việc và thời gian học tập một cách hợp lý để đạt hiệu quả cao nhất.]                                     389 non-null    int64
#  28  Năng lực công nghệ thông tin [Tôi thành thạo trong việc sử dụng các phần mềm cơ bản như Word, Excel, và PowerPoint.]                                           389 non-null    int64
#  29  Năng lực công nghệ thông tin [Tôi có khả năng học và sử dụng các công nghệ và phần mềm mới một cách nhanh chóng.]                                              389 non-null    int64
#  30  Năng lực công nghệ thông tin [Tôi cảm thấy tự tin khi giải quyết các vấn đề kỹ thuật liên quan đến công nghệ thông tin.]                                       389 non-null    int64
#  31  Năng lực công nghệ thông tin [Tôi thường xuyên cập nhật và nâng cao kiến thức về công nghệ thông tin để cải thiện kỹ năng làm việc.]                           389 non-null    int64
#  32  Năng lực công nghệ thông tin [Tôi có khả năng tích hợp và sử dụng các công cụ công nghệ vào học tập và công việc hàng ngày.]                                   389 non-null    int64
#  33  Áp lực công việc [Tôi thường xuyên lo lắng về công việc trong nền kinh tế số]                                                                                  389 non-null    int64
#  34  Áp lực công việc [Tôi cảm thấy không tự tin về năng lực của mình trước yêu cầu của nền kinh tế số]                                                             389 non-null    int64
#  35  Áp lực công việc [Tôi cảm thấy không thể học thêm các điều mới để áp ứng yêu cầu công việc trong nền kinh tế số]                                               389 non-null    int64
#  36  Áp lực công việc [Tôi cho rằng yêu cầu công việc trong nền kinh tế số vượt quá năng lực của tôi]                                                               389 non-null    int64
#  37  Áp lực công việc [Tôi thường xuyên mệt mỏi khi nghĩ về công việc trong tương lai]                                                                              389 non-null    int64
#  38  Trân trọng cảm ơn sự hợp tác của các anh chị và các bạn!!!                                                                                                     52 non-null     object
#  39  Bạn nhận được phiếu khảo sát này từ ai?                                                                                                                        388 non-null    object
# dtypes: float64(1), int64(29), object(10)
# memory usage: 121.7+ KB

# %%
df.describe()
# Out:
#               STT  \
# count  276.000000
# mean   138.500000
# std     79.818544
# min      1.000000
# 25%     69.750000
# 50%    138.500000
# 75%    207.250000
# max    276.000000
#
#        Năng lực giao tiếp và hợp tác [Tôi cảm thấy tự tin khi chia sẻ ý kiến của mình trong các cuộc thảo luận nhóm.]  \
# count                                         389.000000
# mean                                            3.524422
# std                                             1.051531
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực giao tiếp và hợp tác [Tôi lắng nghe ý kiến của người khác một cách tích cực và tôn trọng.]  \
# count                                         389.000000
# mean                                            4.020566
# std                                             0.930352
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        Năng lực giao tiếp và hợp tác [Tôi có thể làm việc nhóm để đạt được mục tiêu chung.]  \
# count                                         389.000000
# mean                                            3.807198
# std                                             0.903230
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực giao tiếp và hợp tác [Tôi thích tham gia vào các hoạt động nhóm và đóng góp ý kiến.]  \
# count                                         389.000000
# mean                                            3.465296
# std                                             1.018870
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực sáng tạo [Tôi thích tìm kiếm những cách thức làm việc mới và hiệu quả hơn.]  \
# count                                         389.000000
# mean                                            3.624679
# std                                             0.970178
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực sáng tạo [Tôi không sợ thất bại khi thử nghiệm những ý tưởng mới.]  \
# count                                         389.000000
# mean                                            3.344473
# std                                             0.960349
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực sáng tạo [Tôi thích giải quyết các vấn đề theo những cách khác biệt.]  \
# count                                         389.000000
# mean                                            3.336761
# std                                             0.985572
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực sáng tạo [Tôi có thể nhìn nhận vấn đề từ nhiều góc độ khác nhau.]  \
# count                                         389.000000
# mean                                            3.465296
# std                                             0.917726
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực sáng tạo [Tôi thích tham gia vào các hoạt động đòi hỏi sự sáng tạo.]  \
# count                                         389.000000
# mean                                            3.519280
# std                                             0.991075
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        ...  \
# count  ...
# mean   ...
# std    ...
# min    ...
# 25%    ...
# 50%    ...
# 75%    ...
# max    ...
#
#        Năng lực công nghệ thông tin [Tôi thành thạo trong việc sử dụng các phần mềm cơ bản như Word, Excel, và PowerPoint.]  \
# count                                         389.000000
# mean                                            3.383033
# std                                             0.997326
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực công nghệ thông tin [Tôi có khả năng học và sử dụng các công nghệ và phần mềm mới một cách nhanh chóng.]  \
# count                                         389.000000
# mean                                            3.295630
# std                                             0.972565
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực công nghệ thông tin [Tôi cảm thấy tự tin khi giải quyết các vấn đề kỹ thuật liên quan đến công nghệ thông tin.]  \
# count                                         389.000000
# mean                                            3.107969
# std                                             1.059402
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực công nghệ thông tin [Tôi thường xuyên cập nhật và nâng cao kiến thức về công nghệ thông tin để cải thiện kỹ năng làm việc.]  \
# count                                         389.000000
# mean                                            3.146530
# std                                             1.028771
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Năng lực công nghệ thông tin [Tôi có khả năng tích hợp và sử dụng các công cụ công nghệ vào học tập và công việc hàng ngày.]  \
# count                                         389.000000
# mean                                            3.457584
# std                                             0.979888
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Áp lực công việc [Tôi thường xuyên lo lắng về công việc trong nền kinh tế số]  \
# count                                         389.000000
# mean                                            3.341902
# std                                             1.150445
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Áp lực công việc [Tôi cảm thấy không tự tin về năng lực của mình trước yêu cầu của nền kinh tế số]  \
# count                                         389.000000
# mean                                            3.097686
# std                                             1.089178
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Áp lực công việc [Tôi cảm thấy không thể học thêm các điều mới để áp ứng yêu cầu công việc trong nền kinh tế số]  \
# count                                         389.000000
# mean                                            2.622108
# std                                             1.118552
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Áp lực công việc [Tôi cho rằng yêu cầu công việc trong nền kinh tế số vượt quá năng lực của tôi]  \
# count                                         389.000000
# mean                                            2.701799
# std                                             1.136790
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Áp lực công việc [Tôi thường xuyên mệt mỏi khi nghĩ về công việc trong tương lai]
# count                                         389.000000
# mean                                            3.164524
# std                                             1.249196
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
# [8 rows x 30 columns]

# %%
df.isnull().sum()
# Out:
# STT                                                                                                                                                              113
# Dấu thời gian                                                                                                                                                      0
# Họ và tên\n(Có thể không cung cấp)                                                                                                                               246
# Email\n(Có thể không cung cấp)                                                                                                                                   344
# Giới tính                                                                                                                                                          0
# Bạn là sinh viên:                                                                                                                                                  0
# Ngành đào tạo:                                                                                                                                                     0
# Anh/chị và các bạn đã chuẩn bị gì cho công việc tương lai?                                                                                                         0
# Năng lực giao tiếp và hợp tác [Tôi cảm thấy tự tin khi chia sẻ ý kiến của mình trong các cuộc thảo luận nhóm.]                                                     0
# Năng lực giao tiếp và hợp tác [Tôi lắng nghe ý kiến của người khác một cách tích cực và tôn trọng.]                                                                0
# Năng lực giao tiếp và hợp tác [Tôi có thể truyền đạt thông tin một cách rõ ràng và hiệu quả.]                                                                      0
# Năng lực giao tiếp và hợp tác [Tôi có thể làm việc nhóm để đạt được mục tiêu chung.]                                                                               0
# Năng lực giao tiếp và hợp tác [Tôi thích tham gia vào các hoạt động nhóm và đóng góp ý kiến.]                                                                      0
# Năng lực sáng tạo [Tôi thích tìm kiếm những cách thức làm việc mới và hiệu quả hơn.]                                                                               0
# Năng lực sáng tạo [Tôi không sợ thất bại khi thử nghiệm những ý tưởng mới.]                                                                                        0
# Năng lực sáng tạo [Tôi thích giải quyết các vấn đề theo những cách khác biệt.]                                                                                     0
# Năng lực sáng tạo [Tôi có thể nhìn nhận vấn đề từ nhiều góc độ khác nhau.]                                                                                         0
# Năng lực sáng tạo [Tôi thích tham gia vào các hoạt động đòi hỏi sự sáng tạo.]                                                                                      0
# Năng lực phân tích công việc [Tôi có thể thu thập và phân tích thông tin một cách hiệu quả.]                                                                       0
# Năng lực phân tích công việc [Tôi có thể nhận biết được các vấn đề và nguyên nhân gốc rễ của chúng.]                                                               0
# Năng lực phân tích công việc [Tôi có thể đánh giá các lựa chọn khác nhau và chọn ra lựa chọn tốt nhất để giải quyết một vấn đề.]                                   0
# Năng lực phân tích công việc [Tôi có thể xác định được các mối quan hệ giữa các yếu tố khác nhau.]                                                                 0
# Năng lực phân tích công việc [Tôi có thể đưa ra các giải pháp hiệu quả cho các vấn đề từ các kiến thức đã học.]                                                    0
# Năng lực quản trị bản thân [Tôi cảm thấy thoải mái và hiệu quả khi làm việc từ xa.]                                                                                0
# Năng lực quản trị bản thân [Tôi có thể cân bằng giữa học tập, làm việc và các hoạt động cá nhân một cách hợp lý.]                                                  0
# Năng lực quản trị bản thân [Tôi có thể duy trì kỷ luật cá nhân trong việc hoàn thành các công việc đúng hạn.]                                                      0
# Năng lực quản trị bản thân [Tôi có thể tự đặt ra mục tiêu và điều chỉnh kế hoạch làm việc của mình phù hợp với tình hình thực tế để đạt được mục tiêu đề ra.]      0
# Năng lực quản trị bản thân [Tôi có thể phân chia công việc và thời gian học tập một cách hợp lý để đạt hiệu quả cao nhất.]                                         0
# Năng lực công nghệ thông tin [Tôi thành thạo trong việc sử dụng các phần mềm cơ bản như Word, Excel, và PowerPoint.]                                               0
# Năng lực công nghệ thông tin [Tôi có khả năng học và sử dụng các công nghệ và phần mềm mới một cách nhanh chóng.]                                                  0
# Năng lực công nghệ thông tin [Tôi cảm thấy tự tin khi giải quyết các vấn đề kỹ thuật liên quan đến công nghệ thông tin.]                                           0
# Năng lực công nghệ thông tin [Tôi thường xuyên cập nhật và nâng cao kiến thức về công nghệ thông tin để cải thiện kỹ năng làm việc.]                               0
# Năng lực công nghệ thông tin [Tôi có khả năng tích hợp và sử dụng các công cụ công nghệ vào học tập và công việc hàng ngày.]                                       0
# Áp lực công việc [Tôi thường xuyên lo lắng về công việc trong nền kinh tế số]                                                                                      0
# Áp lực công việc [Tôi cảm thấy không tự tin về năng lực của mình trước yêu cầu của nền kinh tế số]                                                                 0
# Áp lực công việc [Tôi cảm thấy không thể học thêm các điều mới để áp ứng yêu cầu công việc trong nền kinh tế số]                                                   0
# Áp lực công việc [Tôi cho rằng yêu cầu công việc trong nền kinh tế số vượt quá năng lực của tôi]                                                                   0
# Áp lực công việc [Tôi thường xuyên mệt mỏi khi nghĩ về công việc trong tương lai]                                                                                  0
# Trân trọng cảm ơn sự hợp tác của các anh chị và các bạn!!!                                                                                                       337
# Bạn nhận được phiếu khảo sát này từ ai?                                                                                                                            1
# dtype: int64

# %%
df['Dấu thời gian'] = pd.to_datetime(df['Dấu thời gian'], dayfirst=True)

# %%
df[['Dấu thời gian']]
# Out:
#           Dấu thời gian
# 0   2024-08-19 17:19:14
# 1   2024-08-19 18:29:52
# 2   2024-08-19 18:49:30
# 3   2024-08-19 18:51:51
# 4   2024-08-19 18:52:41
# ..                  ...
# 384 2024-08-24 11:54:24
# 385 2024-08-24 11:54:32
# 386 2024-08-24 11:54:36
# 387 2024-08-24 15:30:29
# 388 2024-08-24 16:49:42
#
# [389 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_84027/2126931359.py in ?()
# ----> 4 from sklearn.preprocessing import StandardScaler
#       5
#       6 scaler = StandardScaler()
#       7 df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
#
# ~/anaconda3/envs/nckh/lib/python3.9/site-packages/sklearn/utils/_set_output.py in ?(self, X, *args, **kwargs)
#     311     @wraps(f)
#     312     def wrapped(self, X, *args, **kwargs):
# --> 313         data_to_wrap = f(self, X, *args, **kwargs)
#     314         if isinstance(data_to_wrap, tuple):
#     315             # only wrap the first output for cross decomposition
#     316             return_tuple = (
#
# ~/anaconda3/envs/nckh/lib/python3.9/site-packages/sklearn/base.py in ?(self, X, y, **fit_params)
#    1094                 )
#    1095
#    1096         if y is None:
#    1097             # fit method of arity 1 (unsupervised transformation)
# -> 1098             return self.fit(X, **fit_params).transform(X)
#    1099         else:
#    1100             # fit method of arity 2 (supervised transformation)
#    1101             return self.fit(X, y, **fit_params).transform(X)
#
# ~/anaconda3/envs/nckh/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y, sample_weight)
#     874             Fitted scaler.
#     875         """
#     876         # Reset internal state before fitting
#     877         self._reset()
# --> 878         return self.partial_fit(X, y, sample_weight)
#
# ~/anaconda3/envs/nckh/lib/python3.9/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# ~/anaconda3/envs/nckh/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y, sample_weight)
#     910         self : object
#     911             Fitted scaler.
#     912         """
#     913         first_call = not hasattr(self, "n_samples_seen_")
# --> 914         X = self._validate_data(
#     915             X,
#     916             accept_sparse=("csr", "csc"),
#     917             dtype=FLOAT_DTYPES,
#
# ~/anaconda3/envs/nckh/lib/python3.9/site-packages/sklearn/base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# ~/anaconda3/envs/nckh/lib/python3.9/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1010                     array = xp.astype(array, dtype, copy=False)
#    1011                 else:
#    1012                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1013             except ComplexWarning as complex_warning:
# -> 1014                 raise ValueError(
#    1015                     "Complex data not supported\n{}\n".format(array)
#    1016                 ) from complex_warning
#    1017
#
# ~/anaconda3/envs/nckh/lib/python3.9/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp, device)
#     747         # Use NumPy API to support order
#     748         if copy is True:
#     749             array = numpy.array(array, order=order, dtype=dtype)
#     750         else:
# --> 751             array = numpy.asarray(array, order=order, dtype=dtype)
#     752
#     753         # At this point array is a NumPy ndarray. We convert it to an array
#     754         # container that is consistent with the input's namespace.
#
# ~/anaconda3/envs/nckh/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# TypeError: float() argument must be a string or a number, not 'Timestamp'
